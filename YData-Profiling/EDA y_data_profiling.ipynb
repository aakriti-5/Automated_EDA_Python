# %%
# !pip install -U ydata-profiling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ydata-profiling in .\AppData\Roaming\Python\Python312\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (1.15.2)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in .\AppData\Roaming\Python\Python312\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (4.70.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (4.6.0)
# Requirement already satisfied: imagehash==4.3.2 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in .\AppData\Roaming\Python\Python312\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in .\AppData\Roaming\Python\Python312\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in .\AppData\Roaming\Python\Python312\site-packages (from imagehash==4.3.2->ydata-profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\AppData\Roaming\Python\Python312\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in .\AppData\Roaming\Python\Python312\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Roaming\Python\Python312\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Roaming\Python\Python312\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.1)
# Requirement already satisfied: joblib>=0.14.1 in .\AppData\Roaming\Python\Python312\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Roaming\Python\Python312\site-packages (from pydantic<3,>=2->ydata-profiling) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\AppData\Roaming\Python\Python312\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\AppData\Roaming\Python\Python312\site-packages (from pydantic<3,>=2->ydata-profiling) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Roaming\Python\Python312\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in .\AppData\Roaming\Python\Python312\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.6 in .\AppData\Roaming\Python\Python312\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in .\AppData\Roaming\Python\Python312\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in .\AppData\Roaming\Python\Python312\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in .\AppData\Roaming\Python\Python312\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in .\AppData\Roaming\Python\Python312\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in .\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in .\AppData\Roaming\Python\Python312\site-packages (26.1.2)
# Collecting pip
#   Downloading pip-26.2.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.2.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 985.5 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.8 MB 985.5 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 745.8 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 745.8 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 745.8 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 599.4 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.3/1.8 MB 664.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 710.8 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 742.4 kB/s  0:00:02
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 26.1.2
#     Uninstalling pip-26.1.2:
#       Successfully uninstalled pip-26.1.2
# Successfully installed pip-26.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from ydata_profiling import ProfileReport
profile=ProfileReport(df,explorative=True)
profile.to_file('output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 7/7 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
