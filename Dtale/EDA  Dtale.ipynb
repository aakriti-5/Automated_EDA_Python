# %%
# !pip install dtale
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/17.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/17.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/17.4 MB 762.0 kB/s eta 0:00:23
#    - -------------------------------------- 0.8/17.4 MB 882.6 kB/s eta 0:00:19
#    -- ------------------------------------- 1.0/17.4 MB 986.7 kB/s eta 0:00:17
#    --- ------------------------------------ 1.3/17.4 MB 972.7 kB/s eta 0:00:17
#    --- ------------------------------------ 1.6/17.4 MB 1.0 MB/s eta 0:00:16
#    ---- ----------------------------------- 1.8/17.4 MB 1.1 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.1/17.4 MB 1.2 MB/s eta 0:00:14
# ...

# %%
import pandas as pd
import dtale 
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://AakritiKandpal:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
